# %%
size = 4
b = bytes(size)
print(b)
# Out:
# b'\x00\x00\x00\x00'

# %%
x = [1, 2, 3, 6]
print(x, "\t", type(x), "\tlen=", len(b))
# Out:
# [1, 2, 3, 6] 	 <class 'list'> 	len= 4

# %%
b = bytes(x)
print(b)
# Out:
# b'\x01\x02\x03\x06'

# %%
x = ['a', 'b', 'c', 'd']
print(x, "\t", type(x))
# Out:
# ['a', 'b', 'c', 'd'] 	 <class 'list'>
