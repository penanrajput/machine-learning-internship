# %%
# Penan Rajput
# Datatype Part 1 Assignment

# %%
n1 = 234
n2 = 679.87
ans = n1 + n2

print(ans, "\t\t", type(ans))
# Out:
# 913.87 		 <class 'float'>

# %%
n3 = 2+3j
n4 = 1+0.4j
ans = n3+n4

print(ans, "\t", type(ans))
# Out:
# (3+3.4j) 	 <class 'complex'>

# %%
n5 = 9
n6  = 1+2j
ans = n5 + n6

print(ans, "\t", type(ans))
# Out:
# (10+2j) 	 <class 'complex'>
