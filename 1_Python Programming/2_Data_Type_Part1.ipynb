# %%
n1 = 234
n2 = 679.87
ans = n1 + n2
print(n1, "\t", type(n1))
print(n2, "\t", type(n2))
print(ans, "\t", type(ans))
# Out:
# 234 	 <class 'int'>
# 679.87 	 <class 'float'>
# 913.87 	 <class 'float'>

# %%
n3 = 2+3j
n4 = 1+0.4j
ans = n3+n4
print(n3, "\t\t", type(n3))
print(n4, "\t", type(n4))
print(ans, "\t", type(ans))
# Out:
# (2+3j) 		 <class 'complex'>
# (1+0.4j) 	 <class 'complex'>
# (3+3.4j) 	 <class 'complex'>

# %%
n5 = 9
n6  = 1+2j
ans = n5 + n6
print(n5, "\t\t", type(n5))
print(n6, "\t\t", type(n6))
print(ans, "\t", type(ans))
# Out:
# 9 		 <class 'int'>
# (1+2j) 		 <class 'complex'>
# (10+2j) 	 <class 'complex'>
